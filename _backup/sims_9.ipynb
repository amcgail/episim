# %%
from bulk_simulation_helper import *

# %%
out_fn = make_file_name( 'full_run_9' )

# %%
def friendHighDegRandTop3(sim, vaccinateN):
    return sampling.friendHighDegRandTopN(sim, vaccinateN, N=3)
def friendHighDegRandTop5(sim, vaccinateN):
    return sampling.friendHighDegRandTopN(sim, vaccinateN, N=5)

strats = [
    friendHighDegRandTop3,
    friendHighDegRandTop5,
]

# %%
VACC_Ps = [0.05, 0.10, 0.20]

# %%
argsx = cp(
    [0.05, 0.1, 0.2], # S2E's
    [0,1] # tneti's
)

# %%
threads = []
for S2E, tneti in argsx:
    t = Thread(target=start_worker, args=(S2E, tneti, VACC_Ps, strats))
    t.start()
    threads.append(t)
        
for t in threads:
    t.join()
# Out:
# loading network...
# loading network...
# loading network...
# loading network...
# loading network...
# loading network...
# Starting on  (0, 0.05, 0.05, 'friendHighDegRandTop3')
# Starting on  (0, 0.2, 0.05, 'friendHighDegRandTop3')
# Starting on  (0, 0.1, 0.05, 'friendHighDegRandTop3')
# simulation 20
# simulation 20
# simulation 20
# simulation 40
# simulation 40
# simulation 40
# simulation 60
# simulation 60
# simulation 60
# Starting on  (1, 0.05, 0.05, 'friendHighDegRandTop3')
# Starting on  (1, 0.2, 0.05, 'friendHighDegRandTop3')
# Starting on  (1, 0.1, 0.05, 'friendHighDegRandTop3')
# simulation 80
# simulation 80
# simulation 80
# simulation 100
# simulation 100
# simulation 100
# simulation 120
# simulation 120
# simulation 120
# simulation 140
# simulation 140
# simulation 140
# simulation 160
# simulation 160
# simulation 160
# simulation 180
# simulation 180
# simulation 180
# simulation 200
# Starting on  (0, 0.1, 0.05, 'friendHighDegRandTop5')
# simulation 200
# Starting on  (0, 0.2, 0.05, 'friendHighDegRandTop5')
# simulation 20
# simulation 200
# Starting on  (0, 0.05, 0.05, 'friendHighDegRandTop5')
# simulation 20
# simulation 40
# simulation 20
# simulation 40
# simulation 60
# simulation 40
# simulation 60
# simulation 80
# simulation 60
# simulation 20
# simulation 80
# simulation 80
# simulation 100
# simulation 100
# simulation 100
# simulation 120
# simulation 20
# simulation 120
# simulation 140
# simulation 120
# simulation 20
# simulation 160
# simulation 140
# simulation 140
# simulation 180
# simulation 160
# simulation 160
# simulation 200
# Starting on  (0, 0.1, 0.1, 'friendHighDegRandTop3')
# simulation 180
# simulation 180
# simulation 20
# simulation 200
# Starting on  (0, 0.2, 0.1, 'friendHighDegRandTop3')
# simulation 200
# Starting on  (0, 0.05, 0.1, 'friendHighDegRandTop3')
# simulation 40
# simulation 20
# simulation 20
# simulation 60
# simulation 40
# simulation 40
# simulation 80
# simulation 60
# simulation 60
# simulation 100
# simulation 80
# simulation 120
# simulation 80
# simulation 100
# simulation 100
# simulation 140
# simulation 120
# simulation 120simulation 160
#
# simulation 40
# simulation 140
# simulation 140
# simulation 180
# simulation 160
# simulation 160
# simulation 200
# Starting on  (0, 0.1, 0.1, 'friendHighDegRandTop5')
# simulation 180
# simulation 180
# simulation 20
# simulation 40
# simulation 40
# simulation 200
# simulation 200
# Starting on  (0, 0.2, 0.1, 'friendHighDegRandTop5')
# Starting on  (0, 0.05, 0.1, 'friendHighDegRandTop5')
# simulation 40
# simulation 20
# simulation 60
# simulation 20
# simulation 80
# simulation 40
# simulation 40
# simulation 100
# simulation 60
# simulation 60
# simulation 120
# simulation 80
# simulation 80
# simulation 140
# simulation 100
# simulation 160
# simulation 100
# simulation 120
# simulation 180
# simulation 120
# simulation 140
# simulation 200
# Starting on  (0, 0.1, 0.2, 'friendHighDegRandTop3')
# simulation 140
# simulation 160
# simulation 20
# simulation 180
# simulation 160
# simulation 40
# simulation 200
# simulation 180
# Starting on  (0, 0.2, 0.2, 'friendHighDegRandTop3')
# simulation 60
# simulation 60
# simulation 200
# Starting on  (0, 0.05, 0.2, 'friendHighDegRandTop3')
# simulation 20
# simulation 80
# simulation 40
# simulation 100
# simulation 20
# simulation 60
# simulation 120
# simulation 40
# simulation 80
# simulation 140
# simulation 60
# simulation 60
# simulation 100
# simulation 60
# simulation 160
# simulation 120
# simulation 180
# simulation 80
# simulation 140
# simulation 200
# Starting on  (0, 0.1, 0.2, 'friendHighDegRandTop5')
# simulation 160
# simulation 100
# simulation 20
# simulation 180
# simulation 40
# simulation 120
# simulation 200
# Starting on  (0, 0.2, 0.2, 'friendHighDegRandTop5')
# simulation 140
# simulation 60
# simulation 20
# simulation 80
# simulation 160
# simulation 100
# simulation 40
# simulation 180
# simulation 120
# simulation 60
# simulation 140
# simulation 200
# Starting on  (0, 0.05, 0.2, 'friendHighDegRandTop5')
# simulation 80
# simulation 160
# simulation 100
# simulation 20
# simulation 180
# simulation 120
# simulation 40
# simulation 200
# simulation 60
# simulation 140
# simulation 80
# simulation 80
# simulation 160
# simulation 100
# simulation 180
# simulation 120
# simulation 200
# simulation 140
# simulation 80
# simulation 160
# simulation 180
# simulation 80
# simulation 200
# simulation 100
# simulation 100
# simulation 100
# simulation 120
# simulation 120
# simulation 120
# simulation 140
# simulation 140
# simulation 140
# simulation 160
# simulation 160
# simulation 160
# simulation 180
# simulation 180
# simulation 200
# simulation 180
# Starting on  (1, 0.05, 0.05, 'friendHighDegRandTop5')
# simulation 200
# Starting on  (1, 0.1, 0.05, 'friendHighDegRandTop5')
# simulation 20
# simulation 200
# Starting on  (1, 0.2, 0.05, 'friendHighDegRandTop5')
# simulation 20
# simulation 40
# simulation 20
# simulation 40
# simulation 60
# simulation 40
# simulation 60
# simulation 80
# simulation 60
# simulation 80
# simulation 100
# simulation 80
# simulation 120
# simulation 100
# simulation 140
# simulation 100
# simulation 120
# simulation 160
# simulation 120
# simulation 140
# simulation 180
# simulation 160
# simulation 140
# simulation 200
# Starting on  (1, 0.05, 0.1, 'friendHighDegRandTop3')
# simulation 180
# simulation 160
# simulation 20
# simulation 200
# Starting on  (1, 0.1, 0.1, 'friendHighDegRandTop3')
# simulation 40
# simulation 180
# simulation 60
# simulation 20
# simulation 200
# Starting on  (1, 0.2, 0.1, 'friendHighDegRandTop3')
# simulation 80
# simulation 40
# simulation 20
# simulation 100
# simulation 60
# simulation 40
# simulation 120
# simulation 80
# simulation 140
# simulation 60
# simulation 100
# simulation 160
# simulation 80
# simulation 180
# simulation 120
# simulation 100
# simulation 200
# Starting on  (1, 0.05, 0.1, 'friendHighDegRandTop5')
# simulation 140
# simulation 20
# simulation 120
# simulation 160
# simulation 40
# simulation 140
# simulation 180
# simulation 60
# simulation 160
# simulation 200
# Starting on  (1, 0.1, 0.1, 'friendHighDegRandTop5')
# simulation 80
# simulation 180
# simulation 20
# simulation 100
# simulation 200
# Starting on  (1, 0.2, 0.1, 'friendHighDegRandTop5')
# simulation 40
# simulation 120
# simulation 20
# simulation 60
# simulation 140
# simulation 40
# simulation 80
# simulation 160
# simulation 60
# simulation 180
# simulation 100
# simulation 200
# Starting on  (1, 0.05, 0.2, 'friendHighDegRandTop3')
# simulation 80
# simulation 120
# simulation 20
# simulation 40
# simulation 100
# simulation 140
# simulation 60
# simulation 160
# simulation 120
# simulation 80
# simulation 180
# simulation 140
# simulation 100
# simulation 200
# Starting on  (1, 0.1, 0.2, 'friendHighDegRandTop3')
# simulation 120
# simulation 160
# simulation 20
# simulation 140
# simulation 180
# simulation 40
# simulation 160
# simulation 200
# Starting on  (1, 0.2, 0.2, 'friendHighDegRandTop3')
# simulation 60
# simulation 180
# simulation 20
# simulation 80
# simulation 200
# Starting on  (1, 0.05, 0.2, 'friendHighDegRandTop5')
# simulation 40
# simulation 100
# simulation 20
# simulation 60
# simulation 120
# simulation 40
# simulation 80
# simulation 140
# simulation 60
# simulation 100
# simulation 160
# simulation 80
# simulation 120
# simulation 100
# simulation 180
# simulation 140
# simulation 120
# simulation 200
# Starting on  (1, 0.1, 0.2, 'friendHighDegRandTop5')
# simulation 140
# simulation 20
# simulation 160
# simulation 160
# simulation 40
# simulation 180
# simulation 180
# simulation 60
# simulation 200
# Starting on  (1, 0.2, 0.2, 'friendHighDegRandTop5')
# simulation 200
# simulation 80
# simulation 20
# simulation 100
# simulation 40
# simulation 120
# simulation 60
# simulation 140
# simulation 80
# simulation 160
# simulation 100
# simulation 180
# simulation 120
# simulation 200
# simulation 140
# simulation 160
# simulation 180
# simulation 200

# %%
len(ms[list(ms.keys())[1]])
# Out:
# 200

# %%
len(ms)
# Out:
# 36

# %%
if True:
    import pickle
    with open(out_fn, 'wb') as outf:
        pickle.dump( ms, outf )
