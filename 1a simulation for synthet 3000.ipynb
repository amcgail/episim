# %%
from simulation_manager import *

# %%
from epi_model import *

# %%
from simulation_helper import *

# %%
argset = argset1 + argset2 + argset3

# %%
# when new
#manager = simulation_manager(generate_network=True, N=3000)

manager = simulation_manager()
manager.load_models('synthetic_3000')

# %%
manager.run_and_checkpoint(
    argset, 
    N_PER=300, 
    interval=5, 
    verbose=False, 
    dump_name='synthetic_3000'
)
# Out:
# starting at 160
# /Users/alecmcgail/envs/epi/lib/python3.8/site-packages/networkx/linalg/graphmatrix.py:187: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   return adjacency_matrix(G, nodelist, dtype, weight)
# Checkpointing after 160/300 simulations
# Checkpointing after 165/300 simulations
# Checkpointing after 170/300 simulations
# Checkpointing after 175/300 simulations
# Checkpointing after 180/300 simulations
# Checkpointing after 185/300 simulations
# Checkpointing after 190/300 simulations
# Checkpointing after 195/300 simulations
# Checkpointing after 200/300 simulations
# Checkpointing after 205/300 simulations
# Checkpointing after 210/300 simulations
# Checkpointing after 215/300 simulations
# Checkpointing after 220/300 simulations
# Checkpointing after 225/300 simulations
# Checkpointing after 230/300 simulations
# Checkpointing after 235/300 simulations
# Checkpointing after 240/300 simulations
# Checkpointing after 245/300 simulations
# Checkpointing after 250/300 simulations
# Checkpointing after 255/300 simulations
# Checkpointing after 260/300 simulations
# Checkpointing after 265/300 simulations
# Checkpointing after 270/300 simulations
# Checkpointing after 275/300 simulations
# Checkpointing after 280/300 simulations
# Checkpointing after 285/300 simulations
# Checkpointing after 290/300 simulations
# Checkpointing after 295/300 simulations
# Checkpointing after 300/300 simulations

# %%
manager.dump_models('synthetic_3000')

# %%
manager.summarize_models()
